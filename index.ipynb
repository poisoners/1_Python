# %% [markdown]
# # Python基础
#
# ## 1 Python安装
#
# ### 1.1 <a href="./1_1_Development Environment Setup.ipynb">Python开发环境设置</a>
#
# ### 1.2 [第一个Python程序](./1_2_First_python_program.ipynb)
#
# ### 1.3 [Jupytet Notebook](./1_3_jupyter_notebook.ipynb)
#
# ## 2 Python基础
#
# ### 2.1 [数据类型和变量](./2_1_data_type_&_variable.ipynb)
#
# ### 2.2 [字符串和编码](./2_2_string_&_code.ipynb)
#
# ### 2.3 [List和Tuple](./2_3_list_&_tuple.ipynb)
#
# ### 2.4 [条件判断](./2_4_conditions.ipynb)
#
# ### 2.5 [循环](./2_5_loop.ipynb)
#
# ### 2.6 [Dict和Set](./2_6_dict_&_set.ipynb)
#
# ## 3 [函数]
#
# ### 3.1 [调用函数](./3_1_function.ipynb)
#
# ### 3.2 [定义函数](./3_2_user-defined_functions..ipynb)
#
# ### 3.3 [函数的参数](./3_3_parameter_of_function.ipynb)
#
# ### 3.4 [递归函数](./3_4_recursive_function;.ipynb)
#
# ## 4 [高级特性]
#
# ### 4.1 [切片](./4_1_slice.ipynb)
#
# ### 4.2 [迭代](./4_2_Iteration.ipynb)
#
# ### 4.3 [列表生成器](./4_3_List_Comprehensions.ipynb)
#
# ### 4.4 [生成器](./4_4_generator.ipynb)
#
# ### 4.5 [迭代器](./4_5_Iterable.ipynb)
#
# ## 5 [函数式编程](./5_0_Functional_Programming.ipynb)
#
# ### 5.1 [高阶函数](./5_1_0_Higher_order_function.ipynb)
#
# #### 5.1.1 [map/reduce](./5_1_1_map_reduce.ipynb)
#
# #### 5.1.2 [filter](./5_1_2_filter.ipynb)
#
# #### 5.1.3 [sorted](./5_1_3_sorted.ipynb)
#
# ### 5.2 [返回函数](./5_2_return_function.ipynb)
#
# ### 5.3 [匿名函数](./5_3_Anonymous_functions.ipynb)
#
# ### 5.4 [装饰器](./5_4_Decorator.ipynb)
#
#
# ### [Python速查表](https://github.com/gto76/python-cheatsheet)

# %% [markdown]
# # Jupyter 配置和使用
#
# ## 一 jupyter notebook 简介
#
# ### 定义
#
# Jupyter Notebook（此前被称为 IPython notebook）是一个交互式笔记本，支持运行 40 多种编程语言。
#
# Jupyter Notebook 的本质是一个 Web 应用程序，便于创建和共享文学化程序文档，支持实时代码，数学方程，可视化和 markdown。 用途包括：数据清理和转换，数值模拟，统计建模，机器学习等等。
#
# 用户可以通过电子邮件，Dropbox，GitHub 和 Jupyter Notebook Viewer，将 Jupyter Notebook 分享给其他人。
#
# 在Jupyter Notebook 中，代码可以实时的生成图像，视频，LaTeX和JavaScript。（摘自[百度百科](https://baike.baidu.com/item/Jupyter/20423051?fr=aladdin)）
#
# ### jupyter 的应用
#
# * 数据挖掘领域中最热门的比赛 Kaggle 里的资料都是Jupyter 格式。
#
#
# * 《经济学人》推荐采用jupyter格式作为其论文提交格式。
#
#
# * 2018年诺贝尔经济学奖获得者Paul Romer 在其个人网站发布文章[Jupyter，Mathematica和研究论文的未来](https://paulromer.net/jupyter-mathematica-and-the-future-of-the-research-paper/)
#
#
# * 《Nature》杂志2018年10月30日在其网站发布文章[Why Jupyter is data scientists’ computational notebook of choice](https://www.nature.com/articles/d41586-018-07196-1)

# %% [markdown]
# ## 二 jupyter notebook 基本操作
#
# ### 主界面
#
# Notebook 打开后，你会在顶部看到三个选项卡：**Files（文件），Running（运行）和 Clusters（集群）**。**Files** 基本上列出了所有的文件，**Running** 显示你当前已经打开的终端和Notebooks，**Clusters** 由 IPython parallel 包提供，用于并行计算。
#
# ![image.png](./pic/jupyter_2_1.png)
#
# ### 新建笔记本
#
# 要打开一个新的 Jupyter Notebook，请单击页面右侧的“New”选项卡。在这里，你有四个选项可供选择：
#
# * Python 3
#
# * Text File (文本文件):得到一个空白的文档,它基本上是一个文本编辑器。你也可以选择一种语言，然后用该语言来写一个脚本。
#
# * Folder (文件夹):创建文件夹
#
# * Terminal (终端):工作方式与 Mac 电脑或 Linux 电脑上的终端完全相同（或者 Windows 上的 cmd ）。它在你的Web浏览器中支持终端会话。比如在这个终端中输入 python ，就可以像在windows命令行状态下一样编写python脚本。
#
# ![image.png](./pic/jupyter_2_2.png)
#
#
#
# **下面，我们将重点介绍 Notebooks，因此我们将从“New”选项中选择 "Python 3" 选项。你会看到如下的截图：**
#
# ![](./pic/jupyter_2_3.png)
#
# 代码上方的菜单栏提供了操作单元格的各种选项：**insert (添加)，edit (编辑)，cut (剪切)，move cell up/down (上下移动单元格)，run cells(在单元格中运行代码)，interupt (停止代码)，save (保存工作)，以及 restart (重新启动内核)**。
#
# ![](./pic/jupyter_2_4.png)
#
#
# 在下拉菜单中（如上所示），你有四个选项：
#
# * **Code（代码）** - 这是你输入代码的地方<br><br>
#
# * **Markdown（标记）** - 这是你输入文本的地方。你可以在运行代码后添加结论，添加注释等。<br><br>
#
# * **Raw NBConvert（原生 NBConvert）** - 这是一个命令行工具，可将你的笔记本转换为另一种格式（如 HTML）<br><br>
#
# * **Heading（标题）** - 你可以将标题添加到单独的小节并使你的 Notebook 看起来干净整洁。这个选项现在已经集成到 Markdown 选项中。添加一个“##”，就可以使之后输入的内容将被视为标题<br><br>
#
# 默认是code（代码），在代码框里输入python语句，点击“运行”按钮，就可以在代码框下方显示运行结果。

# %% [markdown]
# ## 三 Markdown基本语法
#
# 如果在上文所述的下拉菜单中选择**Markdown(标记)**，那么，当前代码框就变成一个可以进行简单排版操作的文本框，通过Markdown简单的标记语法，它可以使普通文本内容具有一定的格式。
#
# ### 1、标题
#
# 在想要设置为标题的文字前面加#来表示
# 一个\#是一级标题，二个\#是二级标题，以此类推。支持六级标题。
#
# 注：\需要在#后跟个空格再写文字\。
#
# 示例:
#
# ```
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题
# #### 这是四级标题
# ##### 这是五级标题
# ###### 这是六级标题
# ```
#
# 效果如下：
#
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题
# #### 这是四级标题
# ##### 这是五级标题
# ###### 这是六级标题
#
# ***
#
# ### 2、字体
#
#
# * **加粗**
#
#
# 要加粗的文字左右分别用两个*号包起来
#
#
# * **斜体**
#
#
# 要倾斜的文字左右分别用一个*号包起来
#
#
# * **斜体加粗**
#
#
# 要倾斜和加粗的文字左右分别用三个*号包起来
#
#
# * **删除线**
#
#
# 要加删除线的文字左右分别用两个\~~号包起来
# 示例：
# ```
# **这是加粗的文字**
# *这是倾斜的文字*`
# ***这是斜体加粗的文字***
# ~~这是加删除线的文字~~
# ```
#
# 效果如下：
#
# **这是加粗的文字**
#
# *这是倾斜的文字*`
#
# ***这是斜体加粗的文字***
#
# ~~这是加删除线的文字~~
#
# ***
#
# ### 3、图片
#
# 语法：
#
# `![图片alt](图片地址 ''图片title'')`
#
# 图片alt是图片无法显示时出现的文字，相当于对图片内容的解释。
# 图片title是图片的标题，当鼠标移到图片上时显示的内容。title可加可不加
#
# 示例：
#
# `![blockchain](https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=702257389,1274025419&fm=27&gp=0.jpg "区块链")`
#
# 效果如下：
#
# ![blockchain](https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=702257389,1274025419&fm=27&gp=0.jpg "区块链")
#
# ***
#
# ### 4、超链接
#
# 语法：
#
# `[超链接名](超链接地址 "超链接title")`
#
# title可加可不加
#
# 示例：
#
# ```
# [简书](http://jianshu.com)
# [百度](http://baidu.com)
# ```
#
# 效果如下：
#
# [简书](http://jianshu.com)
#
# [百度](http://baidu.com)
#
# ***
#
# ### 5、数学公式
#
# 数学公式有两种：行中公式和独立公式。行中公式放在文中与其它文字混编，独立公式单独成行。
#
# 行中公式可以用如下方法表示：
#
#  `$ 数学公式 $`
#
# 独立公式可以用如下方法表示：
#
#  `$$ 数学公式 $$`
#
#  例子：
#
# `$ J_\alpha(x) = \sum_{m=0}^\infty \frac{(-1)^m}{m! \Gamma (m + \alpha + 1)} {\left({ \frac{x}{2} }\right)}^{2m + \alpha} \text {，行内公式示例} $`
#
# 显示：
#
# $ J_\alpha(x) = \sum_{m=0}^\infty \frac{(-1)^m}{m! \Gamma (m + \alpha + 1)} {\left({ \frac{x}{2} }\right)}^{2m + \alpha} \text {，行内公式示例} $
#
# **常见数学公式语法：**
#
# * `^`表示上标,`_` 表示下标。
#
# * 通常使用 `\frac {分子} {分母}` 命令产生一个分数，分数可嵌套。
#
# * 使用 `\int_积分下限^积分上限 {被积表达式}` 来输入一个积分。
#
# * 使用 `\sum_{下标表达式}^{上标表达式} {累加表达式}` 来输入一个累加。
#
# ***
#
# **Markdown语法的详细教程可参考：**
#
# * [最完整的Markdown基础教程](https://www.jianshu.com/p/335db5716248)
#
# * [Cmd Markdown 公式指导手册](https://www.zybuluo.com/codeep/note/163962#1%E5%A6%82%E4%BD%95%E6%8F%92%E5%85%A5%E5%85%AC%E5%BC%8F)

# %% [markdown]
# [机器学习新手必看：Jupyter Notebook入门指南](https://blog.csdn.net/guleileo/article/details/80490921)
